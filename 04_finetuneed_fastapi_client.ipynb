# %% [markdown]
# # Fine tune a Base Model (5 steps)

# %%
# !pip install requests

# %%
import requests
import json

# Replace with your ngrok public URL
API_URL = "https://9be177c0b3a7.ngrok-free.app"

prompt_data = {
    "prompt": "What are the benefits of a plant-based diet?"
}

try:
    response = requests.post(f"{API_URL}/generate", json=prompt_data)
    response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)
    result = response.json()
    print("API Response:", json.dumps(result, indent=2))

except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# API Response: {
#   "response": "system\nYou are a helpful assistant.\nuser\nWhat are the benefits of a plant-based diet?\nassistant\n"
# }
